# %%
# notebooks/model_prototyping.ipynb

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Data generators
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32
DATASET_DIR = '../data'

datagen = ImageDataGenerator(
    rescale=1.0/255.0,
    validation_split=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

train_generator = datagen.flow_from_directory(
    DATASET_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

validation_generator = datagen.flow_from_directory(
    DATASET_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)

# Model prototyping with EfficientNetB0
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout

base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False  # Freeze the base model

model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dropout(0.2),
    Dense(train_generator.num_classes, activation='softmax')
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Found 0 images belonging to 3 classes.
# Found 0 images belonging to 3 classes.
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 8s 0us/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 56
#      43 model = Sequential([
#      44     base_model,
#      45     GlobalAveragePooling2D(),
#      46     Dropout(0.2),
#      47     Dense(train_generator.num_classes, activation='softmax')
#      48 ])
#      50 model.compile(
#      51     optimizer=tf.keras.optimizers.Adam(),
#      52     loss='categorical_crossentropy',
#      53     metrics=['accuracy']
#      54 )
# ---> 56 model.summary()
#
# File c:\Users\gigah\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\gigah\AppData\Local\Programs\Python\Python312\Lib\site-packages\optree\ops.py:747, in tree_map(func, tree, is_leaf, none_is_leaf, namespace, *rests)
#     745 leaves, treespec = _C.flatten(tree, is_leaf, none_is_leaf, namespace)
#     746 flat_args = [leaves] + [treespec.flatten_up_to(r) for r in rests]
# --> 747 return treespec.unflatten(map(func, *flat_args))
#
# ValueError: Undefined shapes are not supported.
